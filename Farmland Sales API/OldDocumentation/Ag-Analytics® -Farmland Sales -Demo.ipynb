# %% [markdown]
# # Ag-Analytics® - Farmland Sales API

# %% [markdown]
# Ag-Analytics® Farmland Sales API provides users with easy and fast access to filter and find land for sale, complete with the sales and geographic data components to get a detailed description of that land’s value. The data of this service is originally provided by [Farmland Finder](https://www.farmlandfinder.com). In this version of Land Value Service API, each parcel/land has a full description of the entire sale/transaction. Multiple parcel/land record can belong to one transaction. In geographic attribute, each result record gives the detailed description of a certain land/parcel itself, while the attribute in ‘sales’ may carry the information for the transaction/sale other than this parcel/land.

# %% [markdown]
# ### Required libraries

# %%
import requests
import json
import pandas as pd
import folium
import mplleaflet
import geojson
import shapely.wkt
import os

# %% [markdown]
# ### Request Parameter Details

# %% [markdown]
# Request URL:  https://ag-analytics.azure-api.net/farmland-sales/
#
#
# 1). __Location Parameters__(Required):
#     To make a valid request,at least one location parameters need to be provided.
#
#     i. State:  The name of State in string format.Title cased.
#
#     ii. County: The name of State in string format. Title cased.This parameter will be valid only if the State parameter is provided
#
#     iii.Bounding_box: Area of interest in geoJSON format(See example below).
#
#
# 2). __Sale Condition Parameters__(optional): Optional parameters to specify response based on sale conditions
#
#     i. Status: Sale Condition of the property. Vaild options are: Sold, For Sale, Expired Listing.
#
#     ii. StartDate (Required only if Status is Sold):Searching starting date of the property Sale Date. In format 'yyyy-mm-dd'
#
#     iii.EndDate (Required only if Status is Sold):Searching end date of the property Sale Date. In format 'yyyy-mm-dd'

# %% [markdown]
# ### Response Description

# %% [markdown]
# __Listing Information__
#
# 1).Listing_id: The unique ID for each listing(transaction).
#
# 2).Entry_Updated:The date of the sales information has been updated
#
# 3).Avg_CSR2: the average The Iowa Corn Suitability Rating(Soil Productivity Index)
#
# 4).CRP: If the property joined the Conservation Reserve Program.(‘Yes’ or ‘No’)
#
# 5).Total_Acres: the total acres of the entire sale
#
# 6).Tillable_Acres: the tillable acres of the sale
#
# 7).Percent_Tillable: the percent tillable area
#
# 8).CRP_Acres: the CRP acres
#
# 9).Sale_Price: the total sale price of the sale record
#
# 10).Price_Acre: the price per acre of the sale record
#
# 11).Status: one of the following values: "For Sale", "Listing Expired", "Sold"
#
# 12).Sale_Condition: one of the following values: "Auction", "Listing"
#
# 13).Listing_Agent: the listing agent name
#
# 14).Buyer: the buyer name as a string
#
# 15).Sale_Date: The sale date string in YYYY-MM-DD format. (When the parcel is still listing, the attribute will be Null
#
# 16).Taxes_total: taxes for the sale as a float
#
# 17).Assessed_Land: If the land/parcel has been assessed
#
# 18).Broker_URL: The URL link to the broker listing webpage as a string
#
#
# __Parcel Information__
#
# 1).Parcel_ID :The unique sale id for each parcel as a string
#
# 2).Parcel: Index of the parcel in one listing(transaction).
#
# 3).Shape: The boundary of the parcel/property in Well Known Text type
#
# 4).GeoJSON: The boundary of the parcel/property in GeoJSON type
#
# 5).Acres: Area of the parcel
#
# 6).State: The state where the parcel/property locates in.
#
# 7).County:The county where the parcel/property locates in.
#
# 8).lat_center: the latitudinal center of the parcel/property as a float value
#
# 9).lng_center: the longitudinal center of the parcel/property as a float value
#
# 10).range: the range as a string (ex: 26W - always include E or W)
#
# 11).sect: the section as string (ex: 17)
#
# 12).twnshp: the township as a string (ex: 78N - always include N or S)
#
# 13).county_name: the county name as a string (Title cased - for ex: Osceola, Polk, etc.)
#
# 14).state_name: the state name as a string (Title cased - for ex: Michigan)
#
# 15).STATEFP: the FIPS to state level as a string
#
# 16).FIPS: the FIPS to county level as a string

# %% [markdown]
# ### Request Parameter Example

# %%
State= "Missouri"
County= "Audrain"
Bounding_box = '{"type":"Feature","properties":{},"geometry":{"type":"Polygon","coordinates":[[[-88.95973205566405,46.68995749641134],[-88.76678466796875,46.68995749641134],[-88.76678466796875,46.7981792512332],[-88.95973205566405,46.7981792512332],[-88.95973205566405,46.68995749641134]]]}}'

Status = "For Sale"
StartDate = "2019-08-08"
EndDate = "2020-01-01"

#Format the inputs()
values = {
    "State":State,
    "County" : County,
#     'Bounding_Box': Bounding_box,
#     'StartDate':StartDate,
#     'EndDate':EndDate,
    "Status":Status
}

# Header for using a subscription key.
headers = {"Ocp-Apim-Subscription-Key": "XXXXXXXXXXXXXXXXXXXXX"}

# %% [markdown]
# ### API Function with GET request

# %%
def LandValueService(values,headers):
    try:
        url = 'https://ag-analytics.azure-api.net/farmland-sales/'
        
        response = requests.get(url, params = values,headers = headers).json()
        print(response.get('status'))
        print(response.get('msg'))
        print(response)
        return response
    
    except Exception as e:
        print(e)
        raise e

# %% [markdown]
# ### API Function with POST request (retiring)

# %% [markdown]
# Note: Starting from June 20th, 2020, we are retiring the post request for FarmLand Sales Services. Sorry for any inconvenience cased by this!

# %%
def LandValueService_Post(values,headers):
    try:
        url = 'https://ag-analytics.azure-api.net/farmland-sales/'
        
        response = requests.post(url, data = values,headers = headers).json()
        print(response.get('status'))
        print(response.get('msg'))
        print(response)
        return response
    
    except Exception as e:
        print(e)
        raise e

# %% [markdown]
# ### Calling API Function and Displaying Response

# %%
LandValueResponse = LandValueService(values,headers)
# Out:
# SUCCESS
# 17 parcel records
# {'msg': '17 parcel records', 'records': {'020AAD4D-056E-4528-A6FC-7D6921FABD94': {'Assessed_Land': None, 'Avg_CSR2': 57.58373999999999, 'Broker_URL': 'https://www.tracyellis.com/idx/mls-20033672-0_50_ac_audrain_co_rd_756_martinsburg_mo_65264', 'Buyer': None, 'CRP': 'No', 'CRP_Acres': None, 'Entry_Updated': '2020-06-01T00:00:00', 'Listing_Agent': 'Meyer & Company Real Estate', 'Listing_id': '020AAD4D-056E-4528-A6FC-7D6921FABD94', 'Percent_Tillable': 84.0, 'Price_Acre': 4950.0, 'Sale_Condition': 'Listing', 'Sale_Date': None, 'Sale_Price': 247500.0, 'Status': 'For Sale', 'Taxes_total': 199.0, 'Tillable_Acres': 42.0, 'Total_Acres': 50.0, 'parcels': [{'Acres': 49.94919629905889, 'County': 'Audrain', 'FIPS': '29007', 'GeoJSON': {'coordinates': [[[-91.7004883289337, 39.05977478982023], [-91.70523047447205, 39.05984143637337], [-91.70506954193115, 39.064848078782056], [-91.70413613319397, 39.06482308810437], [-91.7040717601776, 39.06363185553979], [-91.70178651809692
[-91.86483263969421, 39.16085516556057], [-91.86483263969421, 39.16197820583027], [-91.8636953830719, 39.16192829331011], [-91.8628478050232, 39.16231927377036], [-91.86115264892578, 39.16291821834624], [-91.8598222732544, 39.16314282124745], [-91.8605089187622, 39.16196988707938], [-91.85999393463135, 39.16164545502684], [-91.8595540523529, 39.16127942732513], [-91.859210729599, 39.16074701999565], [-91.85897469520567, 39.15933279346078], [-91.85892105102539, 39.15861735038513], [-91.85866355895996, 39.15769391891593], [-91.85805201530457, 39.15647097750574]]], 'type': 'Polygon'}, 'Parcel': 1, 'Parcel_ID': '5ebee85e526a874b4f70446b', 'STATEFP': '29', 'Shape': 'POLYGON((-91.85805201530457 39.15647097750574, -91.86524033546446 39.156362825201555, -91.86518669128418 39.157818707660574, -91.86573386192322 39.157818707660574, -91.86568021774292 39.16113800702124, -91.86483263969421 39.16085516556057, -91.86483263969421 39.16197820583027, -91.8636953830719 39.16192829331011, -91.8628478050232 39.16231927377036, -91.86115264892578 39.16291821834624, -91.8598222732544 39.16314282124745, -91.8605089187622 39.16196988707938, -91.85999393463135 39.16164545502684, -91.8595540523529 39.16127942732513, -91.859210729599 39.16074701999565, -91.85897469520567 39.15933279346078, -91.85892105102539 39.15861735038513, -91.85866355895996 ...

# %% [markdown]
# ### Format Response

# %%
listing_info =[]
records = LandValueResponse.get('records')
for listing in records:
    parcels_info = records.get(listing).get('parcels')
    list_item = records.get(listing)
    list_item.pop('parcels')
    for parcel in parcels_info:
        parcel.update(list_item)
        listing_info.append(parcel)

listing_db = pd.DataFrame(listing_info)

# %% [markdown]
# ### Display Response

# %%
#Narrow table
listing_db.set_index('Listing_id').T
#Wide table
# listing_db.set_index('Listing_id')
# Out:
# Listing_id                     020AAD4D-056E-4528-A6FC-7D6921FABD94  \
# Acres                                                       49.9492
# Assessed_Land                                                  None
# Avg_CSR2                                                    57.5837
# Broker_URL        https://www.tracyellis.com/idx/mls-20033672-0_...
# Buyer                                                          None
# CRP                                                              No
# CRP_Acres                                                      None
# County                                                      Audrain
# Entry_Updated                                   2020-06-01T00:00:00
# FIPS                                                          29007
# GeoJSON           {'coordinates': [[[-91.7004883289337, 39.05977...
# Listing_Agent                           Meyer & Company Real Estate
# Parcel                                                            1
# Parcel_ID                                  5ee13390526a874bc50b4d81
# Percent_Tillable                                                 84
# Price_Acre                                                     4950
# STATEFP                                                          29
# Sale_Condition                                              Listing
# Sale_Date                                                      None
# Sale_Price                                                   247500
# Shape             POLYGON((-91.7004883289337 39.05977478982023, ...
# State                                                      Missouri
# Status                                                     For Sale
# Taxes_total                                                     199
# Tillable_Acres                                                   42
# Total_Acres                                                      50
# county_name                                                 Audrain
# lat_center                                                  39.0623
# lng_center                                                 -91.7028
# range                                                            7W
# sect                                                             33
# state_name                                                 Missouri
# twnshp                                                          50N
#
# Listing_id                     07F91E8F-6C44-4A23-B262-5E2DE6F2E364  \
# Acres                                                       90.0186
# Assessed_Land                                                  None
# Avg_CSR2                                                    50.7458
# Broker_URL        https://northeastmissourirealty.com/mo/audrain...
# Buyer                                                          None
# CRP                                                              No
# CRP_Acres                                                      None
# County                                                      Audrain
# Entry_Updated                                   2019-08-23T00:00:00
# FIPS                                                          29007
# GeoJSON           {'coordinates': [[[-91.85805201530457, 39.1564...
# Listing_Agent                             Northeast Missouri Realty
# Parcel                                                            1
# Parcel_ID                                  5ebee85e526a874b4f70446b
# Percent_Tillable                                                 28
# Price_Acre                                                     3500
# STATEFP                                                          29
# Sale_Condition                                              Listing
# Sale_Date                                                      None
# Sale_Price                                                   315000
# Shape             POLYGON((-91.85805201530457 39.15647097750574,...
# State                                                      Missouri
# Status                                                     For Sale
# Taxes_total                                                     NaN
# Tillable_Acres                                                   25
# Total_Acres                                                      90
# county_name                                                 Audrain
# lat_center                                                  39.1598
# lng_center                                                 -91.8622
# range                                                            9W
# sect                                                             36
# state_name                                                 Missouri
# twnshp                                                          51N
#
# Listing_id                     3166582E-764F-4C7F-AF9B-A01D9B5ABEF5  \
# Acres                                                           162
# Assessed_Land                                                  None
# Avg_CSR2                                                    45.3809
# Broker_URL        https://meyerlistings.idxbroker.com/idx/detail...
# Buyer                                                          None
# CRP                                                              No
# CRP_Acres                                                      None
# County                                                      Audrain
# Entry_Updated                                   2020-05-26T00:00:00
# FIPS                                                          29007
# GeoJSON           {'coordinates': [[[-91.7866492201864, 39.26381...
# Listing_Agent                           Meyer & Company Real Estate
# Parcel                                                            1
# Parcel_ID                                  5ee1338e526a874bc50b4089
# Percent_Tillable                                                 39
# Price_Acre                                                     2500
# STATEFP                                                          29
# Sale_Condition                                              Listing
# Sale_Date                                                      None
# Sale_Price                                                   397500
# Shape             POLYGON((-91.7866492201864 39.2638133103601, -...
# State                                                      Missouri
# Status                                                     For Sale
# Taxes_total                                                     456
# Tillable_Acres                                                   62
# Total_Acres                                                     159
# county_name                                                 Audrain
# lat_center                                                  39.2619
# lng_center                                                 -91.7914
# range                                                            8W
# sect                                                             27
# state_name                                                 Missouri
# twnshp                                                          52N
#
# Listing_id                     601972A9-3A59-4B8B-B057-A4930FF6A260  \
# Acres                                                       364.507
# Assessed_Land                                                  None
# Avg_CSR2                                                    44.1505
# Broker_URL        https://www.tracyellis.com/idx/mls-20021285-0_...
# Buyer                                                          None
# CRP                                                              No
# CRP_Acres                                                      None
# County                                                      Audrain
# Entry_Updated                                   2020-04-03T00:00:00
# FIPS                                                          29007
# GeoJSON           {'coordinates': [[[-91.85720443725586, 39.1502...
# Listing_Agent                           Meyer & Company Real Estate
# Parcel                                                            1
# Parcel_ID                                  5ebee85d526a874b4f703f6e
# Percent_Tillable                                                  8
# Price_Acre                                                     4384
# STATEFP                                                          29
# Sale_Condition                                              Listing
# Sale_Date                                                      None
# Sale_Price                                                  1.6e+06
# Shape             POLYGON((-91.85720443725586 39.15023114963322,...
# State                                                      Missouri
# Status                                                     For Sale
# Taxes_total                                                     NaN
# Tillable_Acres                                                29.54
# Total_Acres                                                     365
# county_name                                                 Audrain
# lat_center                                                   39.157
# lng_center                                                 -91.8668
# range                                                            9W
# sect                                                             36
# state_name                                                 Missouri
# twnshp                                                          51N
#
# Listing_id                     69489308-7579-4F96-810B-1DE03F28DFEF  \
# Acres                                                       40.6804
# Assessed_Land                                                  None
# Avg_CSR2                                                    39.6497
# Broker_URL        https://www.tracyellis.com/idx/mls-20018845-15...
# Buyer                                                          None
# CRP                                                              No
# CRP_Acres                                                      None
# County                                                      Audrain
# Entry_Updated                                   2020-04-07T00:00:00
# FIPS                                                          29007
# GeoJSON           {'coordinates': [[[-91.856745404149, 39.312099...
# Listing_Agent                                    RE/MAX On the Move
# Parcel                                                            1
# Parcel_ID                                  5ebee85d526a874b4f703e4d
# Percent_Tillable                                                  2
# Price_Acre                                                     5732
# STATEFP                                                          29
# Sale_Condition                                              Listing
# Sale_Date                                                      None
# Sale_Price                                                   235000
# Shape             POLYGON((-91.856745404149 39.3120995351902, -9...
# State                                                      Missouri
# Status                                                     For Sale
# Taxes_total                                                     487
# Tillable_Acres                                                 0.73
# Total_Acres                                                      41
# county_name                                                 Audrain
# lat_center                                                  39.3104
# lng_center                                                 -91.8591
# range                                                            9W
# sect                                                              1
# state_name                                                 Missouri
# twnshp                                                          52N
#
# Listing_id                     81877A3D-79E9-437E-AC75-9763924A7382  \
# Acres                                                       82.0319
# Assessed_Land                                                  None
# Avg_CSR2                                                     46.093
# Broker_URL        https://lpigroup.us/listings/80-acres-audrain-...
# Buyer                                                          None
# CRP                                                              No
# CRP_Acres                                                      None
# County                                                      Audrain
# Entry_Updated                                   2019-11-21T00:00:00
# FIPS                                                          29007
# GeoJSON           {'coordinates': [[[-91.4798211770267, 39.17784...
# Listing_Agent                                Luetkenhaus Properties
# Parcel                                                            1
# Parcel_ID                                  5ebee85e526a874b4f70456d
# Percent_Tillable                                                 50
# Price_Acre                                                     3738
# STATEFP                                                          29
# Sale_Condition                                              Listing
# Sale_Date                                                      None
# Sale_Price                                                   299000
# Shape             POLYGON((-91.4798211770267 39.1778493155894, -...
# State                                                      Missouri
# Status                                                     For Sale
# Taxes_total                                                     NaN
# Tillable_Acres                                                   40
# Total_Acres                                                      80
# county_name                                                 Audrain
# lat_center                                                   39.176
# lng_center                                                 -91.4798
# range                                                            5W
# sect                                                             21
# state_name                                                 Missouri
# twnshp                                                          51N
#
# Listing_id                     8FFBD436-88B4-4CE3-829B-427F75C8B07A  \
# Acres                                                       160.264
# Assessed_Land                                                  None
# Avg_CSR2                                                     36.484
# Broker_URL        http://meyerlistings.idxbroker.com/idx/details...
# Buyer                                                          None
# CRP                                                              No
# CRP_Acres                                                      None
# County                                                      Audrain
# Entry_Updated                                   2020-01-14T00:00:00
# FIPS                                                          29007
# GeoJSON           {'coordinates': [[[-91.87830805778503, 39.1592...
# Listing_Agent                           Meyer & Company Real Estate
# Parcel                                                            1
# Parcel_ID                                  5ebee85d526a874b4f703d91
# Percent_Tillable                                                 13
# Price_Acre                                                     6240
# STATEFP                                                          29
# Sale_Condition                                              Listing
# Sale_Date                                                      None
# Sale_Price                                                   998400
# Shape             POLYGON((-91.87830805778503 39.15928287906368,...
# State                                                      Missouri
# Status                                                     For Sale
# Taxes_total                                                     NaN
# Tillable_Acres                                                21.37
# Total_Acres                                                     160
# county_name                                                 Audrain
# lat_center                                                  39.1589
# lng_center                                                 -91.8722
# range                                                            9W
# sect                                                             36
# state_name                                                 Missouri
# twnshp                                                          51N
#
# Listing_id                     A02146C8-E4FD-48DC-81CA-22357E70B206  \
# Acres                                                       119.323
# Assessed_Land                                                  None
# Avg_CSR2                                                    49.4719
# Broker_URL        http://meyerlistings.idxbroker.com/idx/details...
# Buyer                                                          None
# CRP                                                              No
# CRP_Acres                                                      None
# County                                                      Audrain
# Entry_Updated                                   2020-01-29T00:00:00
# FIPS                                                          29007
# GeoJSON           {'coordinates': [[[-91.85713469982147, 39.1501...
# Listing_Agent                           Meyer & Company Real Estate
# Parcel                                                            1
# Parcel_ID                                  5ebee85d526a874b4f703ee0
# Percent_Tillable                                                  1
# Price_Acre                                                     3825
# STATEFP                                                          29
# Sale_Condition                                              Listing
# Sale_Date                                                      None
# Sale_Price                                                   459000
# Shape             POLYGON((-91.85713469982147 39.150122987738335...
# State                                                      Missouri
# Status                                                     For Sale
# Taxes_total                                                     NaN
# Tillable_Acres                                                 0.71
# Total_Acres                                                     120
# county_name                                                 Audrain
# lat_center                                                  39.1532
# lng_center                                                 -91.8604
# range                                                            9W
# sect                                                             36
# state_name                                                 Missouri
# twnshp                                                          51N
#
# Listing_id                     B10AFF0E-CD91-4740-A671-2F537BFBD815  \
# Acres                                                       31.1425
# Assessed_Land                                                  None
# Avg_CSR2                                                    52.4455
# Broker_URL        https://www.x-tremeteam.co/homes/0-31-ac-parce...
# Buyer                                                          None
# CRP                                                              No
# CRP_Acres                                                      None
# County                                                      Audrain
# Entry_Updated                                   2019-11-22T00:00:00
# FIPS                                                          29007
# GeoJSON           {'coordinates': [[[-91.85981154441833, 39.1631...
# Listing_Agent                           Meyer & Company Real Estate
# Parcel                                                            1
# Parcel_ID                                  5ebee85f526a874b4f7048ba
# Percent_Tillable                                                 27
# Price_Acre                                                     3868
# STATEFP                                                          29
# Sale_Condition                                              Listing
# Sale_Date                                                      None
# Sale_Price                                                   119900
# Shape             POLYGON((-91.85981154441833 39.16311786540495,...
# State                                                      Missouri
# Status                                                     For Sale
# Taxes_total                                                     NaN
# Tillable_Acres                                                  8.5
# Total_Acres                                                      31
# county_name                                                 Audrain
# lat_center                                                   39.161
# lng_center                                                 -91.8625
# range                                                            9W
# sect                                                             36
# state_name                                                 Missouri
# twnshp                                                          51N
#
# Listing_id                     BDE39F2B-3847-45A8-A4EA-7AA88BC492A1  \
# Acres                                                       46.9995
# Assessed_Land                                                  None
# Avg_CSR2                                                    42.6955
# Broker_URL        https://carternetworkrealty.com/property/perfe...
# Buyer                                                          None
# CRP                                                              No
# CRP_Acres                                                      None
# County                                                      Audrain
# Entry_Updated                                   2019-08-02T00:00:00
# FIPS                                                          29007
# GeoJSON           {'coordinates': [[[-91.94186568260193, 39.1613...
# Listing_Agent                                 Carter Network Realty
# Parcel                                                            1
# Parcel_ID                                  5ebee85d526a874b4f703d14
# Percent_Tillable                                                 43
# Price_Acre                                                     6330
# STATEFP                                                          29
# Sale_Condition                                              Listing
# Sale_Date                                                      None
# Sale_Price                                                   297500
# Shape             POLYGON((-91.94186568260193 39.161329340305684...
# State                                                      Missouri
# Status                                                     For Sale
# Taxes_total                                                 1685.14
# Tillable_Acres                                                   20
# Total_Acres                                                      47
# county_name                                                 Audrain
# lat_center                                                  39.1603
# lng_center                                                 -91.9402
# range                                                            9W
# sect                                                             32
# state_name                                                 Missouri
# twnshp                                                          51N
#
# Listing_id                     F4D910C4-EDC8-4085-B4C7-A5CB0907DDF7  \
# Acres                                                       23.1351
# Assessed_Land                                                  None
# Avg_CSR2                                                    57.3544
# Broker_URL                    http://link.flexmls.com/lxxgos4h0mi,3
# Buyer                                                          None
# CRP                                                              No
# CRP_Acres                                                      None
# County                                                      Audrain
# Entry_Updated                                   2018-11-20T00:00:00
# FIPS                                                          29007
# GeoJSON           {'coordinates': [[[-91.89082791105844, 39.2513...
# Listing_Agent           Don Emery & Associates, RE/MAX Boone Realty
# Parcel                                                            1
# Parcel_ID                                  5ebee861526a874b4f7053a2
# Percent_Tillable                                                 65
# Price_Acre                                                     3750
# STATEFP                                                          29
# Sale_Condition                                              Listing
# Sale_Date                                                      None
# Sale_Price                                                   236250
# Shape             POLYGON((-91.89082791105844 39.25135529487836,...
# State                                                      Missouri
# Status                                                     For Sale
# Taxes_total                                                     NaN
# Tillable_Acres                                                40.95
# Total_Acres                                                      63
# county_name                                                    None
# lat_center                                                  39.2536
# lng_center                                                 -91.8887
# range                                                            9W
# sect                                                             26
# state_name                                                 Missouri
# twnshp                                                          52N
#
# Listing_id                     F4D910C4-EDC8-4085-B4C7-A5CB0907DDF7  \
# Acres                                                        9.8223
# Assessed_Land                                                  None
# Avg_CSR2                                                    57.3544
# Broker_URL                    http://link.flexmls.com/lxxgos4h0mi,3
# Buyer                                                          None
# CRP                                                              No
# CRP_Acres                                                      None
# County                                                      Audrain
# Entry_Updated                                   2018-11-20T00:00:00
# FIPS                                                          29007
# GeoJSON           {'coordinates': [[[-91.88772338888333, 39.2568...
# Listing_Agent           Don Emery & Associates, RE/MAX Boone Realty
# Parcel                                                            2
# Parcel_ID                                  5ebee861526a874b4f7053a3
# Percent_Tillable                                                 65
# Price_Acre                                                     3750
# STATEFP                                                          29
# Sale_Condition                                              Listing
# Sale_Date                                                      None
# Sale_Price                                                   236250
# Shape             POLYGON((-91.88772338888333 39.2568484197778, ...
# State                                                      Missouri
# Status                                                     For Sale
# Taxes_total                                                     NaN
# Tillable_Acres                                                40.95
# Total_Acres                                                      63
# county_name                                                    None
# lat_center                                                  39.2564
# lng_center                                                 -91.8891
# range                                                            9W
# sect                                                             26
# state_name                                                 Missouri
# twnshp                                                          52N
#
# Listing_id                     F4D910C4-EDC8-4085-B4C7-A5CB0907DDF7  \
# Acres                                                       5.00246
# Assessed_Land                                                  None
# Avg_CSR2                                                    57.3544
# Broker_URL                    http://link.flexmls.com/lxxgos4h0mi,3
# Buyer                                                          None
# CRP                                                              No
# CRP_Acres                                                      None
# County                                                      Audrain
# Entry_Updated                                   2018-11-20T00:00:00
# FIPS                                                          29007
# GeoJSON           {'coordinates': [[[-91.88768325296036, 39.2581...
# Listing_Agent           Don Emery & Associates, RE/MAX Boone Realty
# Parcel                                                            3
# Parcel_ID                                  5ebee861526a874b4f7053a4
# Percent_Tillable                                                 65
# Price_Acre                                                     3750
# STATEFP                                                          29
# Sale_Condition                                              Listing
# Sale_Date                                                      None
# Sale_Price                                                   236250
# Shape             POLYGON((-91.88768325296036 39.258130328153044...
# State                                                      Missouri
# Status                                                     For Sale
# Taxes_total                                                     NaN
# Tillable_Acres                                                40.95
# Total_Acres                                                      63
# county_name                                                    None
# lat_center                                                  39.2578
# lng_center                                                 -91.8889
# range                                                            9W
# sect                                                             26
# state_name                                                 Missouri
# twnshp                                                          52N
#
# Listing_id                     F4D910C4-EDC8-4085-B4C7-A5CB0907DDF7  \
# Acres                                                      0.861657
# Assessed_Land                                                  None
# Avg_CSR2                                                    57.3544
# Broker_URL                    http://link.flexmls.com/lxxgos4h0mi,3
# Buyer                                                          None
# CRP                                                              No
# CRP_Acres                                                      None
# County                                                      Audrain
# Entry_Updated                                   2018-11-20T00:00:00
# FIPS                                                          29007
# GeoJSON           {'coordinates': [[[-91.88770080356457, 39.2570...
# Listing_Agent           Don Emery & Associates, RE/MAX Boone Realty
# Parcel                                                            4
# Parcel_ID                                  5ebee861526a874b4f7053a5
# Percent_Tillable                                                 65
# Price_Acre                                                     3750
# STATEFP                                                          29
# Sale_Condition                                              Listing
# Sale_Date                                                      None
# Sale_Price                                                   236250
# Shape             POLYGON((-91.88770080356457 39.257023469555136...
# State                                                      Missouri
# Status                                                     For Sale
# Taxes_total                                                     NaN
# Tillable_Acres                                                40.95
# Total_Acres                                                      63
# county_name                                                    None
# lat_center                                                  39.2574
# lng_center                                                 -91.8889
# range                                                            9W
# sect                                                             26
# state_name                                                 Missouri
# twnshp                                                          52N
#
# Listing_id                     F4D910C4-EDC8-4085-B4C7-A5CB0907DDF7  \
# Acres                                                       17.2373
# Assessed_Land                                                  None
# Avg_CSR2                                                    57.3544
# Broker_URL                    http://link.flexmls.com/lxxgos4h0mi,3
# Buyer                                                          None
# CRP                                                              No
# CRP_Acres                                                      None
# County                                                      Audrain
# Entry_Updated                                   2018-11-20T00:00:00
# FIPS                                                          29007
# GeoJSON           {'coordinates': [[[-91.88780689554716, 39.2548...
# Listing_Agent           Don Emery & Associates, RE/MAX Boone Realty
# Parcel                                                            5
# Parcel_ID                                  5ebee861526a874b4f7053a6
# Percent_Tillable                                                 65
# Price_Acre                                                     3750
# STATEFP                                                          29
# Sale_Condition                                              Listing
# Sale_Date                                                      None
# Sale_Price                                                   236250
# Shape             POLYGON((-91.88780689554716 39.25489880593812,...
# State                                                      Missouri
# Status                                                     For Sale
# Taxes_total                                                     NaN
# Tillable_Acres                                                40.95
# Total_Acres                                                      63
# county_name                                                    None
# lat_center                                                  39.2525
# lng_center                                                  -91.889
# range                                                            9W
# sect                                                             26
# state_name                                                 Missouri
# twnshp                                                          52N
#
# Listing_id                     F4D910C4-EDC8-4085-B4C7-A5CB0907DDF7  \
# Acres                                                       5.88434
# Assessed_Land                                                  None
# Avg_CSR2                                                    57.3544
# Broker_URL                    http://link.flexmls.com/lxxgos4h0mi,3
# Buyer                                                          None
# CRP                                                              No
# CRP_Acres                                                      None
# County                                                      Audrain
# Entry_Updated                                   2018-11-20T00:00:00
# FIPS                                                          29007
# GeoJSON           {'coordinates': [[[-91.89069716041537, 39.2493...
# Listing_Agent           Don Emery & Associates, RE/MAX Boone Realty
# Parcel                                                            6
# Parcel_ID                                  5ebee861526a874b4f7053a7
# Percent_Tillable                                                 65
# Price_Acre                                                     3750
# STATEFP                                                          29
# Sale_Condition                                              Listing
# Sale_Date                                                      None
# Sale_Price                                                   236250
# Shape             POLYGON((-91.89069716041537 39.24930124806062,...
# State                                                      Missouri
# Status                                                     For Sale
# Taxes_total                                                     NaN
# Tillable_Acres                                                40.95
# Total_Acres                                                      63
# county_name                                                    None
# lat_center                                                    39.25
# lng_center                                                 -91.8907
# range                                                            9W
# sect                                                             35
# state_name                                                 Missouri
# twnshp                                                          52N
#
# Listing_id                     FB68CC65-9003-44A6-A387-01BCACC38DDA
# Acres                                                       66.3606
# Assessed_Land                                                  None
# Avg_CSR2                                                     52.295
# Broker_URL        https://p.flexmls.com/jacquelineleonard/portal...
# Buyer                                                          None
# CRP                                                              No
# CRP_Acres                                                      None
# County                                                      Audrain
# Entry_Updated                                   2018-11-16T00:00:00
# FIPS                                                          29007
# GeoJSON           {'coordinates': [[[-91.60296857357025, 39.2041...
# Listing_Agent                                        Central Realty
# Parcel                                                            1
# Parcel_ID                                  5ebee85d526a874b4f703aa4
# Percent_Tillable                                                 85
# Price_Acre                                                     4746
# STATEFP                                                          29
# Sale_Condition                                              Listing
# Sale_Date                                                      None
# Sale_Price                                                   318000
# Shape             POLYGON((-91.60296857357025 39.204108370864496...
# State                                                      Missouri
# Status                                                     For Sale
# Taxes_total                                                     NaN
# Tillable_Acres                                                56.95
# Total_Acres                                                      67
# county_name                                                 Audrain
# lat_center                                                  39.2039
# lng_center                                                 -91.5981
# range                                                            6W
# sect                                                             17
# state_name                                                 Missouri
# twnshp                                                          51N

# %% [markdown]
# ### Visualize Parcels on Map

# %%
#Display parcels on map
zoom_point=listing_db['GeoJSON'][0]['coordinates'][0][0]
m = folium.Map([zoom_point[1],zoom_point[0]],tiles='Cartodb Positron', zoom_start=11,width='70%', height='100%')
for shape in listing_db['GeoJSON']:
    folium.GeoJson(shape).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Download Response

# %%
download_path = '<---path on your local directory--->' # ex:r'C:\Users\YourName\Downloads'
listing_db.to_csv(os.path.join(download_path,'FarmLand_Listing.csv'))
