# %% [markdown]
# # Ag Analytics-PRISM Precipitation-Demo

# %% [markdown]
# Source data obtained from PRISM Climate Group, Oregon State University. API provides accumulated precipitation to date for a given location.

# %%
import requests
import json
import time
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
import datetime as dt
import pandas as pd
from matplotlib import dates
from matplotlib.dates import DateFormatter
# %autosave 0

# %% [markdown]
# ### API details
#
# ####Request URL:
# https://ag-analytics.azure-api.net/precipitation/[?month][&day][&year][&coordinateX][&coordinateY][&startYear]
#
# ####Parameters:
#
# ***month***
# ***day***
# ***year - ***
# Define the end year of data range.
#
# ***coordinateX - ***
# X coordinate for location desired.
#
# ***coordinateY - ***
# Y coordinate for location desired.
#
# ***startYear - ***
# Define the start year of data range.
#
# In order to get Ocp-Apim-Subscription-Key, please click on this link https://analytics.ag/Session/SignInToAPIPayment

# %% [markdown]
# ### Request Parameters

# %%
month=1
day=1
year=2016
coordinateX=-88.9893385940128
coordinateY=40.010959177421654
startYear=1981

headers={'Ocp-Apim-Subscription-Key': 'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx'}

# %% [markdown]
# ###  API Function

# %%
def get_precipitation(month,day,year,coordinateX,coordinateY,startYear,headers):
    try:
        url = "https://ag-analytics.azure-api.net/precipitation/?month={}&day={}&year={}&coordinateX={}&coordinateY={}&startYear={}".format(month,day,year,coordinateX,coordinateY,startYear)
     
        response = (requests.get(url,headers=headers).text)
        print(response)
        response_json = json.loads(response)
        time.sleep(0.5)
        return response_json
    
    except Exception as e:
        raise e

# %% [markdown]
# ### Calling API Function and Displaying API Response

# %%
prep=get_precipitation(month,day,year,coordinateX,coordinateY,startYear,headers)
# Out:
# [{"CumPrecipitation":[{"Date":"1-1","year":2016,"Accumulated Precipitation":0.0},{"Date":"1-10","year":2016,"Accumulated Precipitation":12.08},{"Date":"1-11","year":2016,"Accumulated Precipitation":12.08},{"Date":"1-12","year":2016,"Accumulated Precipitation":12.08},{"Date":"1-13","year":2016,"Accumulated Precipitation":12.08},{"Date":"1-14","year":2016,"Accumulated Precipitation":12.08},{"Date":"1-15","year":2016,"Accumulated Precipitation":12.08},{"Date":"1-16","year":2016,"Accumulated Precipitation":17.84},{"Date":"1-17","year":2016,"Accumulated Precipitation":18.55},{"Date":"1-18","year":2016,"Accumulated Precipitation":18.55},{"Date":"1-19","year":2016,"Accumulated Precipitation":18.55},{"Date":"1-2","year":2016,"Accumulated Precipitation":0.0},{"Date":"1-20","year":2016,"Accumulated Precipitation":25.73},{"Date":"1-21","year":2016,"Accumulated Precipitation":25.73},{"Date":"1-22","year":2016,"Accumulated Precipitation":25.73},{"Date":"1-23","year":2016,"Accumulated Precipitation":25.73},{"Date":"1-24","year":2016,"Accumulated Precipitation":25.73},{"Date":"1-25","year":2016,"Accumulated Precipitation":25.73},{"Date":"1-26","year":2016,"Accumulated Precipitation":25.73},{"Date":"1-27","year":2016,"Accumulated Precipitation":25.73},{"Date":"1-28","year":2016,"Accumulated Precipitation":25.73},{"Date":"1-29","year":2016,"Accumulated Precipitation":25.73},{"Date":"1-3","year":2016,"Accumulated Precipitation":0.0},{"Date":"1-30","year":2016,"Accumulated Precipitation":25.73},{"Date":"1-31","year":2016,"Accumulated Precipitation":25.73},{"Date":"1-4","year":2016,"Accumulated Precipitation":0.0},{"Date":"1-5","year":2016,"Accumulated Precipitation":0.0},{"Date":"1-6","year":2016,"Accumulated Precipitation":0.0},{"Date":"1-7","year":2016,"Accumulated Precipitation":0.0},{"Date":"1-8","year":2016,"Accumulated Precipitation":1.85},{"Date":"1-9","year":2016,"Accumulated Precipitation":3.85},{"Date":"10-1","year":2016,"Accumulated Precipitation":766.674},{"Date":"10-10","year":2016,"Accumulated Precipitation":774.246},{"Date":"10-11","year":2016,"Accumulated Precipitation":774.246},{"Date":"10-12","year":2016,"Accumulated Precipitation":776.119},{"Date":"10-13","year":2016,"Accumulated Precipitation":779.682},{"Date":"10-14","year":2016,"Accumulated Precipitation":779.682},{"Date":"10-15","year":2016,"Accumulated Precipitation":779.682},{"Date":"10-16","year":2016,"Accumulated Precipitation":783.35300000000007},{"Date":"10-17","year":2016,"Accumulated Precipitation":796.62600000000009},{"Date":"10-18","year":2016,"Accumulated Precipitation":796.62600000000009},{"Date":"10-19","year":2016,"Accumulated Precipitation":796.62600000000009},{"Date":"10-2","year":2016,"Accumulated Precipitation":767.627},{"Date":"10-20","year":2016,"Accumulated Precipitation":807.9140000000001},{"Date":"10-21","year":2016,"Accumulated Precipitation":809.53800000000012},{"Date":"10-22","year":2016,"Accumulated Precipitation":809.53800000000012},{"Date":"10-23","year":2016,"Accumulated Precipitation":809.53800000000012},{"Date":"10-24","year":2016,"Accumulated Precipitation":809.53800000000012},{"Date":"10-25","year":2016,"Accumulated Precipitation":809.53800000000012},{"Date":"10-26","year":2016,"Accumulated Precipitation":812.21000000000015},{"Date":"10-27","year":2016,"Accumulated Precipitation":816.66300000000012},{"Date":"10-28","year":2016,"Accumulated Precipitation":816.66300000000012},{"Date":"10-29","year":2016,"Accumulated Precipitation":816.66300000000012},{"Date":"10-3","year":2016,"Accumulated Precipitation":767.627},{"Date":"10-30","year":2016,"Accumulated Precipitation":816.66300000000012},{"Date":"10-31","year":2016,"Accumulated Precipitation":816.66300000000012},{"Date":"10-4","year":2016,"Accumulated Precipitation":767.627},{"Date":"10-5","year":2016,"Accumulated Precipitation":767.627},{"Date":"10-6","year":2016,"Accumulated Precipitation":772.41},{"Date":"10-7","year":2016,"Accumulated Precipitation":774.246},{"Date":"10-8","year":2016,"A ...

# %% [markdown]
# ### Displaying Output

# %%
res=pd.DataFrame()

for i,j in enumerate(prep):
    
    for index in prep[i].keys():
            
        
        df = pd.DataFrame.from_records(j[index])
        df.rename(columns={'Accumulated Precipitation':index},inplace=True)
        
        if res.empty:
            res=df
        else:
            res=res.merge(df,on="Date",how="outer")
            
            

# removing feb 29th as the pandas datetime cannot handle just the feb 29th without year

res = res[~(res['Date']=="2-29")]

res['Date']=pd.to_datetime(res['Date'], format = '%m-%d')



dfmt = dates.DateFormatter('%b %d')
res.set_index('Date',inplace=True)


res=res.sort_index()




fig, ax = plt.subplots(figsize=(10,10), linewidth=5)

if 'year' in res.columns:
    res.drop(columns=["year"],inplace=True)
ax.plot(res)
ax.set_xlabel("Date")
ax.set_ylabel("Accumulated Precipitation")
ax.set_title("Precipitation")
ax.legend(res.columns)
ax.xaxis.set_major_formatter(dfmt)
